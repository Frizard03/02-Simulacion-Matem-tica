# %% [markdown]
# # T01 - Markdown

# %% [markdown]
# ## Alejandro Frizard

# %% [markdown]
# **Una pequeña presentación e introducción a mi carrera...**

# %% [markdown]
# Mi nombre es *Alejandro Frizard* y estudio..

# %% [markdown]
# ![ing_fin.jpg](attachment:ing_fin.jpg)

# %% [markdown]
# Mi carrera principalmente consiste de 3 areas
# - Matemáticas
# - Finanzas
# - Programación

# %% [markdown]
# Se utilizan ecuaciones todo el tiempo como $ M = C × (1 + i)n $ me parece muy interesante el análisis de riesgo en la construcción de portafolios de inversión, ya que tomar una desición con base en información nos permite acertar un mayor numero de veces, es decir, reducir el riesgo

# %% [markdown]
# Al requerir mucho tiempo estudiar, es necesario structurar mi día de la siguiente manera:
#
# 1. Levantarme
# 2. Estudiar
# 3. Comer
# 4. Estudiar más
# 5. Dormir
